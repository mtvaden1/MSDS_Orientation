# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %% [markdown]
# ## Distributions converge as N increases:

# %% [markdown]
# ### Binomial Distributions:

# %%
r = [1, 5, 10, 50, 100, 500, 1000, 10000]

for n in r:
    binomial = np.random.binomial(n, .5, 1000)
    mu, std = norm.fit(binomial) 
  
    plt.hist(binomial, bins=15, density=True)
    
    xmin, xmax = plt.xlim()
    x = np.linspace(xmin, xmax, 1000)
    p = norm.pdf(x, mu, std)
    
    plt.plot(x, p, 'k', linewidth=1)
    plt.title("n: {:.2f}".format(n))
    plt.show()

# %% [markdown]
# ### Normal Distribution:

# %%
print(mu, std)
# normal distribution with same mean and standard deviation as sufficiently large binomial distribution
normal = np.random.normal(mu, std, 1000)

plt.hist(normal, bins=15, density=True)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 1000)
p = norm.pdf(x, mu, std)
  
plt.plot(x, p, 'k', linewidth=1) 
plt.title("n: 10000")
plt.show()
# Out:
# 5000.374 49.12618572614813

# %% [markdown]
# Code online found to help show the normal distribution line [here](https://www.geeksforgeeks.org/how-to-plot-normal-distribution-over-histogram-in-python/)
